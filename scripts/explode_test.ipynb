# %%
import pathlib
from datetime import datetime
from typing import List, Tuple, Union, Dict

import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql import Column

from pyspark.sql import DataFrame
from pyspark.sql import SparkSession
from pyspark.sql import Window

# %%
# master configuration to use only 4 CPU cores
spark = SparkSession.builder.master("local[4]").getOrCreate()

# basic configuration to use only a reasonable number of partitions
spark.conf.set("spark.sql.shuffle.partition", 4)

# configuration to work in UTC
spark.conf.set("spark.sql.session.timeZone", "UTC")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/08/07 12:41:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
path = "/Users/emilianofrigo/Downloads/test_read/"

# Read JSONL file
df = (
    spark.read
    # .option("multiline", "true")
    .json(path)
)
# Out:
# 23/08/07 12:41:41 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df.printSchema()
# Out:
# root
#  |-- _airbyte_ab_id: string (nullable = true)
#  |-- _airbyte_data: struct (nullable = true)
#  |    |-- AdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- PerUnitAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- ProductDescription: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: string (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |    |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentType: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |-- AffordabilityExpenseEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- AffordabilityExpenseReversalEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ChargebackEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- CouponPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ChargeComponent: struct (nullable = true)
#  |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- ClipOrRedemptionCount: long (nullable = true)
#  |    |    |    |-- CouponId: string (nullable = true)
#  |    |    |    |-- FeeComponent: struct (nullable = true)
#  |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |-- PaymentEventId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerCouponDescription: string (nullable = true)
#  |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- DebtRecoveryEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- FBALiquidationEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- GuaranteeClaimEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ImagingServicesFeeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- LoanServicingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- NetworkComminglingTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- PayWithAmazonEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ProductAdsPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- baseValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- invoiceId: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- transactionType: string (nullable = true)
#  |    |    |    |-- transactionValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- RefundEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- RemovalShipmentAdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentEventId: string (nullable = true)
#  |    |    |    |-- MerchantOrderId: string (nullable = true)
#  |    |    |    |-- OrderId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RemovalShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- AdjustedQuantity: long (nullable = true)
#  |    |    |    |    |    |-- FulfillmentNetworkSKU: string (nullable = true)
#  |    |    |    |    |    |-- RemovalShipmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- RevenueAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxAmountAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxWithheldAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- RemovalShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- MerchantOrderId: string (nullable = true)
#  |    |    |    |-- OrderId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RemovalShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FulfillmentNetworkSKU: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: long (nullable = true)
#  |    |    |    |    |    |-- RemovalShipmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- Revenue: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxWithheld: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- RentalTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RetrochargeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- BaseTax: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RetrochargeTaxWithheldList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- ShippingTax: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- SAFETReimbursementEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerDealPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dealDescription: string (nullable = true)
#  |    |    |    |-- dealId: string (nullable = true)
#  |    |    |    |-- eventType: string (nullable = true)
#  |    |    |    |-- feeAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- feeType: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- totalAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- SellerReviewEnrollmentPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ServiceFeeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- FeeDescription: string (nullable = true)
#  |    |    |    |-- FeeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ServiceProviderCreditEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ShipmentSettleEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TaxWithholdingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TrialShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- _metadata: struct (nullable = true)
#  |    |    |-- report_id: string (nullable = true)
#  |    |    |-- request_params: struct (nullable = true)
#  |    |    |    |-- MaxResultsPerPage: long (nullable = true)
#  |    |    |    |-- PostedAfter: string (nullable = true)
#  |    |    |    |-- PostedBefore: string (nullable = true)
#  |-- _airbyte_emitted_at: long (nullable = true)

# %%
df.count()
# Out:
# 809
# 23/08/07 18:12:40 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 2083846 ms exceeds timeout 120000 ms
# 23/08/07 18:12:40 WARN SparkContext: Killing executors is not supported by current scheduler.

# %%
df.show(truncate=False)
# Out:
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |_airbyte_ab_id                      |_airbyte_data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |7b6250d7-fd2e-45b4-9399-8f918c7d3409|{[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{203-3549654-9199504, Amazon.co.uk, 2023-06-15T00:00:20Z, 203-3549654-9199504, [{[{{16.66, GBP}, Principal}, {{3.33, GBP}, Tax}, {{0.0, GBP}, GiftWrap}, {{0.0, GBP}, GiftWrapTax}, {{0.0, GBP}, ShippingCharge}, {{0.0, GBP}, ShippingTax}], [{{-2.58, GBP}, FBAPerUnitFulfillmentFee}, {{-3.06, GBP}, Commission}, {{0.0, GBP}, FixedClosingFee}, {{0.0, GBP}, GiftwrapChargeback}, {{0.0, GBP}, ShippingChargeback}, {{0.0, GBP}, VariableClosingFee}], null, 29742210499562, null, 1, SPLNBC002}]}, {305-2422713-8691553, Amazon.de, 2023-06-15T00:01:08Z, 305-2422713-8691553, [{[{{20.16, EUR}, Principal}, {{3.83, EUR}, Tax}, {{0.0, EUR}, GiftWrap}, {{0.0, EUR}, GiftWrapTax}, {{0.0, EUR}, ShippingCharge}, {{0.0, EUR}, ShippingTax}], [{{-6.44, EUR}, FBAPerUnitFulfillmentFee}, {{-3.6, EUR}, Commission}, {{0.0, EUR}, FixedClosingFee}, {{0.0, EUR}, GiftwrapChargeback}, {{0.0, EUR}, ShippingChargeback}, {{0.0, EUR}, VariableClosingFee}], [{MarketplaceFacilitator, [{{-3.83, EUR}, MarketplaceFacilitatorVAT-Principal}, {{0.0, EUR}, MarketplaceFacilitatorVAT-Shipping}]}], 29754344892722, null, 1, KGP-NBR-WW-BL-NA}]}, {205-6379825-1893103, Amazon.co.uk, 2023-06-15T00:02:22Z, 205-6379825-1893103, [{[{{4.99, GBP}, Principal}, {{1.0, GBP}, Tax}, {{0.0, GBP}, GiftWrap}, {{0.0, GBP}, GiftWrapTax}, {{0.0, GBP}, ShippingCharge}, {{0.0, GBP}, ShippingTax}], [{{-2.09, GBP}, FBAPerUnitFulfillmentFee}, {{-0.49, GBP}, Commission}, {{0.0, GBP}, FixedClosingFee}, {{0.0, GBP}, GiftwrapChargeback}, {{0.0, GBP}, ShippingChargeback}, {{0.0, GBP}, VariableClosingFee}], null, 29746232116402, null, 1, KGPTAP001}]}, {204-7044205-5349967, Amazon.co.uk, 2023-06-15T00:02:45Z, 204-7044205-5349967, [{[{{4.99, GBP}, Principal}, {{1.0, GBP}, Tax}, {{0.0, GBP}, GiftWrap}, {{0.0, GBP}, GiftWrapTax}, {{2.49, GBP}, ShippingCharge}, {{0.5, GBP}, ShippingTax}], [{{-2.09, GBP}, FBAPerUnitFulfillmentFee}, {{-0.49, GBP}, Commission}, {{0.0, GBP}, FixedClosingFee}, {{0.0, GBP}, GiftwrapChargeback}, {{0.0, GBP}, ShippingChargeback}, {{0.0, GBP}, VariableClosingFee}], null, 29749353847362, [{{0.0, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}, {{-2.49, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{-0.5, GBP}, PAWS-V2-22886240117-91, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}, {{0.0, GBP}, UK Core Free Shipping 2015/04/08 23-59-11-975, PromotionMetaDataDefinitionValue}], 1, KGPTAP001}]}, {204-8534903-5665114, Amazon.co.uk, 2023-06-15T00:03:04Z, 204-8534903-5665114, [{[{{9.99, GBP}, Principal}, {{2.0, GBP}, Tax}, {{0.0, GBP}, GiftWrap}, {{0.0, GBP}, GiftWrapTax}, {{4.16, GBP}, ShippingCharge}, {{0.83, GBP}, ShippingTax}], [{{-3.36, GBP}, FBAPerUnitFulfillmentFee}, {{-1.83, GBP}, Commission}, {{0.0, GBP}, FixedClosingFee}, {{0.0, GBP}, GiftwrapChargeback}, {{-4.16, GBP}, ShippingChargeback}, {{0.0, GBP}, VariableClosingFee}], null, 
-06-16T01:02:03Z, 402-6721849-9517108, [{[{{16.39, EUR}, Principal}, {{0.0, EUR}, Tax}, {{0.0, EUR}, GiftWrap}, {{0.0, EUR}, GiftWrapTax}, {{0.0, EUR}, ShippingCharge}, {{0.0, EUR}, ShippingTax}], [{{-6.52, EUR}, FBAPerUnitFulfillmentFee}, {{-2.53, EUR}, Commission}, {{0.0, EUR}, FixedClosingFee}, {{0.0, EUR}, GiftwrapChargeback}, {{0.0, EUR}, RenewedProgramFee}, {{0.0, EUR}, ShippingChargeback}, {{0.0, EUR}, VariableClosingFee}], null, 29782837789802, null, 1, T8-XDV2-S713}]}, {404-7283361-3814736, Amazon.it, 2023-06-16T01:02:03Z, 404-7283361-3814736, [{[{{16.39, EUR}, Principal}, {{3.77, EUR}, Tax ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
def explode(df: DataFrame, config: dict) -> DataFrame:
    columns = config["columns"]
    if not isinstance(columns, list):
        columns = [columns]
    for column in columns:
        df.withColumn(column, F.explode(column))
        print(f"    {column} count: {df.count()}")
    return df

# %%
def flatten(input_sdf: DataFrame):
    event_sdf = input_sdf.withColumn(
        "AmazonOrderId", F.explode("_airbyte_data.ServiceFeeEventList.AmazonOrderId")
    )

    return event_sdf

# %%
df_test = flatten(df)

# %%
df_test.printSchema()
df_test.show()
# Out:
# root
#  |-- _airbyte_ab_id: string (nullable = true)
#  |-- _airbyte_data: struct (nullable = true)
#  |    |-- AdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- PerUnitAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- ProductDescription: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: string (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |    |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentType: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |-- AffordabilityExpenseEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- AffordabilityExpenseReversalEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ChargebackEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- CouponPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ChargeComponent: struct (nullable = true)
#  |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- ClipOrRedemptionCount: long (nullable = true)
#  |    |    |    |-- CouponId: string (nullable = true)
#  |    |    |    |-- FeeComponent: struct (nullable = true)
#  |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |-- PaymentEventId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerCouponDescription: string (nullable = true)
#  |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- DebtRecoveryEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- FBALiquidationEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- GuaranteeClaimEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ImagingServicesFeeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- LoanServicingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- NetworkComminglingTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- PayWithAmazonEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ProductAdsPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- baseValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- invoiceId: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- transactionType: string (nullable = true)
#  |    |    |    |-- transactionValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- RefundEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- RemovalShipmentAdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentEventId: string (nullable = true)
#  |    |    |    |-- MerchantOrderId: string (nullable = true)
#  |    |    |    |-- OrderId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RemovalShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- AdjustedQuantity: long (nullable = true)
#  |    |    |    |    |    |-- FulfillmentNetworkSKU: string (nullable = true)
#  |    |    |    |    |    |-- RemovalShipmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- RevenueAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxAmountAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxWithheldAdjustment: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- RemovalShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- MerchantOrderId: string (nullable = true)
#  |    |    |    |-- OrderId: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RemovalShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FulfillmentNetworkSKU: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: long (nullable = true)
#  |    |    |    |    |    |-- RemovalShipmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- Revenue: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxWithheld: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- RentalTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RetrochargeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- BaseTax: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- RetrochargeTaxWithheldList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- ShippingTax: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- SAFETReimbursementEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerDealPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- dealDescription: string (nullable = true)
#  |    |    |    |-- dealId: string (nullable = true)
#  |    |    |    |-- eventType: string (nullable = true)
#  |    |    |    |-- feeAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- feeType: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- totalAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- SellerReviewEnrollmentPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ServiceFeeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- FeeDescription: string (nullable = true)
#  |    |    |    |-- FeeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ServiceProviderCreditEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ShipmentSettleEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TaxWithholdingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TrialShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- _metadata: struct (nullable = true)
#  |    |    |-- report_id: string (nullable = true)
#  |    |    |-- request_params: struct (nullable = true)
#  |    |    |    |-- MaxResultsPerPage: long (nullable = true)
#  |    |    |    |-- PostedAfter: string (nullable = true)
#  |    |    |    |-- PostedBefore: string (nullable = true)
#  |-- _airbyte_emitted_at: long (nullable = true)
#  |-- AmazonOrderId: string (nullable = true)
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-------------------+-------------------+
# |      _airbyte_ab_id|       _airbyte_data|_airbyte_emitted_at|      AmazonOrderId|
# +--------------------+--------------------+-------------------+-------------------+
# |63d4c2f1-d257-465...|{[], [], [], [], ...|      1691033334643|               null|
# |e9df3674-4d53-4d3...|{[{{2.41, GBP}, [...|      1691033336076|               null|
# |e9df3674-4d53-4d3...|{[{{2.41, GBP}, [...|      1691033336076|               null|
# |a78dc35a-0c63-483...|{[], [], [], [], ...|      1691033343522|407-6935280-8029123|
# |a78dc35a-0c63-483...|{[], [], [], [], ...|      1691033343522|407-6935280-8029123|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |d4395b9b-cf39-476...|{[], [], [], [], ...|      1691033344033|               null|
# |71084499-ac98-473...|{[], [], [], [], ...|      1691033349891|171-4521846-4013915|
# |71084499-ac98-473...|{[], [], [], [], ...|      1691033349891|171-4521846-4013915|
# |71084499-ac98-473...|{[], [], [], [], ...|      1691033349891|171-4521846-4013915|
# |71084499-ac98-473...|{[], [], [], [], ...|      1691033349891|171-4521846-4013915|
# |8c2040e1-4ceb-408...|{[{{6.15, GBP}, [...|      1691033426329|         23061414I3|
# |5bf36220-045b-4e6...|{[], [], [], [], ...|      1691033428052|405-0815917-6878764|
# |5bf36220-045b-4e6...|{[], [], [], [], ...|      1691033428052|405-0815917-6878764|
# |f32d8580-b7e3-410...|{[{{7.35, GBP}, [...|      1691033496320|028-4424730-2413128|
# +--------------------+--------------------+-------------------+-------------------+
# only showing top 20 rows

# %%
df_test.count()
# Out:
# 472
