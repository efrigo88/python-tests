# %%
def filter_streams(stream_dict, desired_names):
    filtered_streams = []
    for stream_info in stream_dict["streams"]:
        stream_name = stream_info["stream"]["name"]
        if stream_name in desired_names:
            filtered_streams.append(stream_info)
    return {"streams": filtered_streams}

# %%
# List of dictionaries (your input data)
stream_list = [
    {
        "stream": {
            "name": "sales_order",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "amount": {"type": "string"},
                            "trandate": {"type": "string"},
                            "externalid": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "amountunbilled": {"type": "string"},
                            "grossamount": {"type": "string"},
                            "customform": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "netamountnotax": {"type": "string"},
                            "terms": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "fxamount": {"type": "string"},
                            "memomain": {"type": "string"},
                            "taxtotal": {"type": "string"},
                            "custbody5": {"type": "string"},
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custbody7": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "subsidiarynohierarchy": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "transactionnumber": {"type": "string"},
                            "fxamountunbilled": {"type": "string"},
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "sales_order",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "purchase_order",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "amount": {"type": "string"},
                            "closedate": {"type": "string"},
                            "vendor.custentity_payment_term_deposit": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "vendor.custentity_payment_term_balance": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "trandate": {"type": "string"},
                            "amountremaining": {"type": "string"},
                            "fxamountremaining": {"type": "string"},
                            "subsidiary": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "grossamount": {"type": "string"},
                            "netamountnotax": {"type": "string"},
                            "terms": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "fxamount": {"type": "string"},
                            "taxtotal": {"type": "string"},
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "transactionnumber": {"type": "string"},
                            "class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "purchase_order",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "purchase_order_line_item",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "quantity": {"type": "string"},
                            "trandate": {"type": "string"},
                            "payingTransaction.exchangerate": {"type": "string"},
                            "memo": {"type": "string"},
                            "fxrate": {"type": "string"},
                            "subsidiary": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "vendor.altname": {"type": "string"},
                            "rate": {"type": "string"},
                            "duedate": {"type": "string"},
                            "item.class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "item.itemid": {"type": "string"},
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "purchase_order_line_item",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "b2b_pnl",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "item": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "amount": {"type": "string"},
                            "cseg_ns_htl_chnl_cs": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "quantity": {"type": "string"},
                            "mainline": {"type": "string"},
                            "trandate": {"format": "date", "type": "string"},
                            "type": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custtype": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "account.externalid": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "postingperiod": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "subsidiarynohierarchy": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "account": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "customer.country": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custbody_incoterm_for_sale": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "b2b_pnl",
            "selected": True,
            "suggested": False,
        },
    },
]
print(type(stream_list))
# List of desired stream names
desired_names = ["sales_order", "purchase_order"]

# Filter streams based on desired names
filtered_streams_dict = filter_streams(stream_list, desired_names)

# Print the filtered streams dictionary
print(filtered_streams_dict)
# Out:
# <class 'list'>
# ...

# %%
def filter_streams(stream_list, desired_names):
    filtered_streams = []
    for stream_info in stream_list:
        stream_name = stream_info["stream"]["name"]
        if stream_name in desired_names:
            filtered_streams.append(stream_info)
    return filtered_streams


# List of dictionaries (your input data)
stream_list = [
    {
        "stream": {
            "name": "sales_order",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "amount": {"type": "string"},
                            "trandate": {"type": "string"},
                            "externalid": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "amountunbilled": {"type": "string"},
                            "grossamount": {"type": "string"},
                            "customform": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "netamountnotax": {"type": "string"},
                            "terms": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "fxamount": {"type": "string"},
                            "memomain": {"type": "string"},
                            "taxtotal": {"type": "string"},
                            "custbody5": {"type": "string"},
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custbody7": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "subsidiarynohierarchy": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "transactionnumber": {"type": "string"},
                            "fxamountunbilled": {"type": "string"},
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "sales_order",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "purchase_order",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "amount": {"type": "string"},
                            "closedate": {"type": "string"},
                            "vendor.custentity_payment_term_deposit": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "vendor.custentity_payment_term_balance": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "trandate": {"type": "string"},
                            "amountremaining": {"type": "string"},
                            "fxamountremaining": {"type": "string"},
                            "subsidiary": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "grossamount": {"type": "string"},
                            "netamountnotax": {"type": "string"},
                            "terms": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "fxamount": {"type": "string"},
                            "taxtotal": {"type": "string"},
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "transactionnumber": {"type": "string"},
                            "class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "required": ["loc"],
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "purchase_order",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "purchase_order_line_item",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "quantity": {"type": "string"},
                            "trandate": {"type": "string"},
                            "payingTransaction.exchangerate": {"type": "string"},
                            "memo": {"type": "string"},
                            "fxrate": {"type": "string"},
                            "subsidiary": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "vendor.altname": {"type": "string"},
                            "rate": {"type": "string"},
                            "duedate": {"type": "string"},
                            "item.class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "currency": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "statusref": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "item.itemid": {"type": "string"},
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "purchase_order_line_item",
            "selected": True,
            "suggested": False,
        },
    },
    {
        "stream": {
            "name": "b2b_pnl",
            "jsonSchema": {
                "$schema": "http://json-schema.org/draft-07/schema#",
                "type": "object",
                "properties": {
                    "record-type": {"type": "string"},
                    "values": {
                        "type": "object",
                        "properties": {
                            "tranid": {"type": "string"},
                            "item": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "amount": {"type": "string"},
                            "cseg_ns_htl_chnl_cs": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "quantity": {"type": "string"},
                            "mainline": {"type": "string"},
                            "trandate": {"format": "date", "type": "string"},
                            "type": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custtype": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "account.externalid": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "postingperiod": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "subsidiarynohierarchy": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "class": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "entity": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "account": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "customer.country": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                            "custbody_incoterm_for_sale": {
                                "type": "array",
                                "items": {
                                    "type": "object",
                                    "properties": {
                                        "text": {"type": "string"},
                                        "value": {"type": "string"},
                                    },
                                },
                            },
                        },
                    },
                    "id": {"type": "string"},
                },
            },
            "supportedSyncModes": ["full_refresh"],
            "defaultCursorField": [],
            "sourceDefinedPrimaryKey": [["id"]],
        },
        "config": {
            "syncMode": "full_refresh",
            "cursorField": [],
            "destinationSyncMode": "overwrite",
            "primaryKey": [["id"]],
            "aliasName": "b2b_pnl",
            "selected": True,
            "suggested": False,
        },
    },
]

# List of desired stream names
desired_names = ["sales_order", "purchase_order"]

# Filter streams based on desired names
filtered_streams = filter_streams(stream_list, desired_names)

print(filtered_streams)


# # Print the filtered streams
# for stream_info in filtered_streams:
#     print(stream_info)
# Out:
# [{'stream': {'name': 'sales_order', 'jsonSchema': {'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'record-type': {'type': 'string'}, 'values': {'type': 'object', 'properties': {'tranid': {'type': 'string'}, 'amount': {'type': 'string'}, 'trandate': {'type': 'string'}, 'externalid': {'type': 'array', 'items': {'type': 'object', 'properties': {'text': {'type': 'string'}, 'value': {'type': 'string'}}}}, 'amountunbilled': {'type': 'string'}, 'grossamount': {'type': 'string'}, 'customform': {'type': 'array', 'items': {'type': 'object', 'properties': {'text': {'type': 'string'}, 'value': {'type': 'string'}}}}, 'netamountnotax': {'type': 'string'}, 'terms': {'type': 'array', 'items': {'type': 'object', 'properties': {'text': {'type': 'string'}, 'value': {'type': 'string'}}}}, 'fxamount': {'type': 'string'}, 'memomain': {'type': 'string'}, 'taxtotal': {'type': 'string'}, 'custbody5': {'type': 'string'}, 'currency': {'type': 'array', 'items': {'type': '
# ...
