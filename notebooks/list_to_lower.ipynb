# %%
lst = [
'_Quote_T1_document_fee__Customs',
 'Additional_Declaration_Lines_Customs',
 'Additional_Drop_Off_Charge_Destination',
 'Additional_Notes',
 'Advance_Commercial_Information_Origin',
 'Air_Cargo_Advanced_Screening_Freight',
 'Air_Freight_Freight',
 'Airline_Terminal_Destination',
 'Airline_Terminal_Origin',
 'Airport_Storage_Destination',
 'Airport_Transfer_Destination',
 'Airport_Transfer_Origin',
 'Automated_Manifest_System_Freight',
 'Automated_Manifest_System_Origin',
 'Bill_of_Lading_Amendment_Fee_Origin',
 'Bobtail_Destination',
 'Booking_Fee_Origin',
 'CCAM_Origin',
 'Canadian_Food_Inspection_Agency_Fee_Customs',
 'Cargo_Inspection_Origin',
 'Cartage_Base_Destination',
 'Cartage_Base_Origin',
 'Chassis_Destination',
 'Chassis_Split_Destination',
 'China_Inspection_and_Quarantine_Fee_Origin',
 'Classification_Fee_Customs',
 'Clean_Truck_Fee_Destination',
 'Congestion_Fee_Destination',
 'Congestion_Fee_Origin',
 'Container_Drop_Charge_Destination',
 'Container_Drop_Charge_Origin',
 'Container_Freight_Station_Destination',
 'Container_Freight_Station_Origin',
 'Container_Unloading_Fee_Destination',
 'Credit_Line_Items',
 'Crossdocking_Fee_Origin',
 'Customs_Admin_Fee_Customs',
 'Customs_Document_Fee_Customs',
 'Customs_Duty_Customs',
 'Customs_Examination_Customs',
 'Customs_Examination_Origin',
 'DG_Creation_and_Inspection_VAS_Origin',
 'DG_Labeling_VAS_Origin',
 'Delivery_Order_Destination',
 'Destination_Actual_Arrival_Date',
 'Destination_Container_Freight_Station_Fee_Destination',
 'Destination_Document_Destination',
 'Destination_Handling_Destination',
 'Destination_Terminal_Handling_Charge_Destination',
 'Destination_VAT_Import_Tax_Customs',
 'Detention_Destination',
 'Devanning_Fee_Destination',
 'Disbursement_Service_Fee_Customs',
 'Document_Destination',
 'Document_Origin',
 'Drayage_Base_Destination',
 'Drayage_Base_Origin',
 'Drop_Fee_Destination',
 'Dry_Run_Charge_Destination',
 'Dry_Run_Charge_Origin',
 'EDI_Charge_Origin',
 'ENS_Fee_Origin',
 'Empty_Pickup_Origin',
 'Energy_Surcharge_Destination',
 'Energy_Surcharge_Freight',
 'Entry_Summary_Declaration_Origin',
 'Equipment_Origin',
 'Equipment_Inspection_Charge_Destination',
 'Export_Customs_Clearance_Customs',
 'Export_Customs_Clearance_Origin',
 'FBA_Prep_VAS_Destination',
 'FCL__20_Container_Freight',
 'FCL__40_Container_Freight',
 'FCL__40_HQ_Container_Freight',
 'FLEXID',
 'Fee_Handling_Origin',
 'Food_and_Drug_Administration_Fee_Customs',
 'Freight_Insurance_Additional',
 'Fuel_Surcharge_Destination',
 'Fuel_Surcharge_Freight',
 'Fuel_Surcharge_Origin',
 'GSTHST_Goods__Services_Tax_Customs',
 'Goods_and_Service_Tax_on_Imported_Goods_Customs',
 'Goods_and_Service_Tax_on_Services_Customs',
 'Handling_Destination',
 'Handling_Origin',
 'Harbor_Maintenance_Fee_Customs',
 'Hazardous_Surcharge_Destination',
 'Honey_Fee_Customs',
 'ISPS_Destination',
 'Import_Customs_Clearance_Customs',
 'Import_Handling_Destination',
 'Import_Security_Filing_Customs',
 'Import_Service_Charge_Destination',
 'InBond_Fee_Customs',
 'Indirect_Representation_Surcharge_Customs',
 'Invoice_Amount',
 'Invoice_Currency',
 'Invoice_Due_Date',
 'Invoice_Issue_Date',
 'Invoice_Number',
 'Invoice_Paid_Date',
 'LCL__Ocean_Freight_Freight',
 'Labeling_VAS_Additional',
 'Labeling_VAS_Destination',
 'Lift_On_Lift_Off_Charge_Destination',
 'Liftgate_Destination',
 'Liftgate_Origin',
 'Linehaul_Destination',
 'Long_Term_Storage_Destination',
 'Long_Term_Storage_Origin',
 'Management_Fee_Customs',
 'Merchandise_Processing_Fee_Customs',
 'Merchandise_Processing_Informal_Fee_Customs',
 'Ocean_Demurrage_Destination',
 'Onboarding_Fee_Customs',
 'Origin_Container_Freight_Station_Fee_Origin',
 'Origin_Document_Origin',
 'Origin_Gate_Fee_Origin',
 'Origin_VAT_Export_Tax_Customs',
 'Origin_ValueAdded_Tax_Origin',
 'Other_Additional',
 'Other_Government_Agency_Declaration_Customs',
 'Outstanding_Amount',
 'Overweight_Surcharge_Origin',
 'PO_Shipment_Tag',
 'Paid_Amount',
 'Pallet_Exchange_Destination',
 'Pallet_Out_VAS_Destination',
 'Palletization_Additional',
 'Palletization_Destination',
 'Palletization_Origin',
 'Peak_Season_Surcharge_Freight',
 'Pick_Up__Delivery_Destination',
 'Pick_Up__Delivery_Origin',
 'Pick_Up_Origin',
 'Pier_Pass_20_Ft_Container_Destination',
 'Pier_Pass_40_Ft_Container_Destination',
 'Pier_Pass_40_Ft_HC_Container_Destination',
 'Port__Admin_Fees_Customs',
 'Port_Charge_Origin',
 'PrePull_Destination',
 'PrePull_Origin',
 'Rail_Terminal_Storage_Destination',
 'SSL_Rail_Demurrage_Destination',
 'Screening_Charge_Origin',
 'Seal_Fee_Origin',
 'Security__Manifest_Fee_Origin',
 'Security_Charge_Destination',
 'Shipment_Name',
 'Special_Delivery_Destination',
 'Special_Delivery_Origin',
 'Stop_Off_Fee_Destination',
 'Stop_Off_Fee_Origin',
 'T_Documents_Customs',
 'Telex_Release_Fee_Origin',
 'Terminal_Breakdown_Destination',
 'Terminal_Handling_Charge_Destination',
 'Terminal_Handling_Charge_Origin',
 'Total_Additional_Amount',
 'Total_Credit_Amount',
 'Total_Customs_Amount',
 'Total_Destination_Amount',
 'Total_Freight_Amount',
 'Total_Origin_Amount',
 'Toxic_Substances_Control_Act_Fee_Customs',
 'Transload_Destination',
 'Trucking_FTL_Base_Freight',
 'Trucking_Wait_Fee_Destination',
 'Unloading_Origin',
 'VGM_Fee_Origin',
 'Vehicle_Loading_Origin',
 'Vehicle_Unloading_Origin',
 'Warehouse__Valueadd_Origin',
 'Warehouse_Storage_VAS_Destination',
 'Warehouse_Storage_VAS_Origin',
 'Yard_Storage_Destination',
 'eManifest_Filing_Fee_Freight',
]

# %%
new_list = []

for i in lst:
    new_list.append(i.lower())

new_list
# Out:
# ['_quote_t1_document_fee__customs',
#  'additional_declaration_lines_customs',
#  'additional_drop_off_charge_destination',
#  'additional_notes',
#  'advance_commercial_information_origin',
#  'air_cargo_advanced_screening_freight',
#  'air_freight_freight',
#  'airline_terminal_destination',
#  'airline_terminal_origin',
#  'airport_storage_destination',
#  'airport_transfer_destination',
#  'airport_transfer_origin',
#  'automated_manifest_system_freight',
#  'automated_manifest_system_origin',
#  'bill_of_lading_amendment_fee_origin',
#  'bobtail_destination',
#  'booking_fee_origin',
#  'ccam_origin',
#  'canadian_food_inspection_agency_fee_customs',
#  'cargo_inspection_origin',
#  'cartage_base_destination',
#  'cartage_base_origin',
#  'chassis_destination',
#  'chassis_split_destination',
#  'china_inspection_and_quarantine_fee_origin',
#  'classification_fee_customs',
#  'clean_truck_fee_destination',
#  'congestion_fee_destination',
#  'congestion_fee_origin',
# ...

# %%
# Open the file in write mode
with open('output.txt', 'w') as file:
    # Convert list elements to strings and join them with commas
    list_string = ', \n'.join(map(str, new_list))
    
    # Write the string to the file
    file.write(list_string)

# File is automatically closed after the 'with' block
