# %%
list_to_clean = [
    "ams_numbers: string",
    "actual_arrival_port_dwell_time: integer",
    "actual_arrival_port_to_delivery_transit_time: integer",
    "actual_crd_to_pickup_dwell_time: integer",
    "actual_departure_port_dwell_time: integer",
    "actual_departure_port_to_arrival_port_transit_time: integer",
    "actual_departure_port_to_discharge_port_transit_time: integer",
    "actual_discharge_port_dwell_time: integer",
    "actual_discharge_port_to_arrival_port_transit_time: integer",
    "actual_door_to_door_transit_time: integer",
    "actual_flexportresponsible_transit_time: integer",
    "actual_pickup_to_departure_port_transit_time: integer",
    "actual_port_to_door_transit_time: integer",
    "actual_port_to_port_transit_time: integer",
    "arrival_carrier: string",
    "arrival_notice_submission_date: date",
    "arrival_port: string",
    "arrival_port_actual_arrival_date: date",
    "arrival_port_actual_departure_date: date",
    "arrival_port_address: string",
    "arrival_port_country: string",
    "arrival_port_estimated_arrival_date: date",
    "arrival_port_estimated_departure_date: date",
    "arrival_port_planned_arrival_date: date",
    "arrival_port_planned_departure_date: date",
    "arrival_tracking_number: string",
    "arrival_vessel_name: string",
    "booking_confirmed_date: date",
    "booking_received_date: date",
    "booking_to_crd_lead_time: integer",
    "booking_to_so_release_lead_time: integer",
    "brand_shipment_tag: string",
    "ci__pl_upload_date: date",
    "co2e_emissions: double",
    "crd_last_updated_date: date",
    "cy_cutoff_date: date",
    "carrier_booking_number: string",
    "carrier_si_cutoff_date: date",
    "carrier_service_string: string",
    "carrier_vgm_cutoff_date: date",
    "certificate_of_origin_upload_date: date",
    "cleared_customs_date: date",
    "commercial_invoice_numbers: string",
    "consignee: string",
    "container_numbers: string",
    "country_trade_lane: string",
    "departure_carrier: string",
    "departure_port: string",
    "departure_port_actual_arrival_date: date",
    "departure_port_actual_departure_date: date",
    "departure_port_address: string",
    "departure_port_country: string",
    "departure_port_estimated_arrival_date: date",
    "departure_port_estimated_departure_date: date",
    "departure_port_planned_arrival_date: date",
    "departure_port_planned_departure_date: date",
    "departure_tracking_number: string",
    "departure_vessel_name: string",
    "destination_actual_arrival_date: date",
    "destination_address: string",
    "destination_appointment_required: string",
    "destination_cfs_actual_arrival_date: date",
    "destination_cfs_actual_departure_date: date",
    "destination_cfs_address: string",
    "destination_cfs_country: string",
    "destination_cfs_estimated_arrival_date: date",
    "destination_cfs_estimated_departure_date: date",
    "destination_cfs_name: string",
    "destination_cfs_planned_arrival_date: date",
    "destination_cfs_planned_departure_date: date",
    "destination_carrier: string",
    "destination_company_names: string",
    "destination_contact_emails: string",
    "destination_contact_names: string",
    "destination_contact_phones: string",
    "destination_country: string",
    "destination_delivery_notes: string",
    "destination_delivery_order_sent_date: date",
    "destination_estimated_arrival_date: date",
    "destination_name: string",
    "destination_planned_arrival_date: date",
    "destination_scheduled_delivery_date: date",
    "destination_target_delivery_date: date",
    "destination_tracking_number: integer",
    "discharge_carrier: string",
    "discharge_port: string",
    "discharge_port_actual_arrival_date: date",
    "discharge_port_actual_departure_date: date",
    "discharge_port_address: string",
    "discharge_port_country: string",
    "discharge_port_estimated_arrival_date: date",
    "discharge_port_estimated_departure_date: date",
    "discharge_port_planned_arrival_date: date",
    "discharge_port_planned_departure_date: date",
    "discharge_tracking_number: string",
    "discharge_vessel_name: string",
    "entry_numbers: string",
    "exceptions: string",
    "fcl__lcl: string",
    "firms_code: string",
    "flex_id: string",
    "ftl__ltl: string",
    "freight_carriers: string",
    "freight_type: string",
    "house_bill_of_lading_numbers: string",
    "house_bill_of_lading_release_date: date",
    "house_bill_of_lading_scope: string",
    "isf_filing_date: date",
    "itn_number: string",
    "import_customs_agent: string",
    "importer_of_record_ior_shipment_tag: string",
    "incoterm: string",
    "loading_carrier: string",
    "loading_port: string",
    "loading_port_actual_arrival_date: date",
    "loading_port_actual_departure_date: date",
    "loading_port_address: string",
    "loading_port_country: string",
    "loading_port_estimated_arrival_date: date",
    "loading_port_estimated_departure_date: date",
    "loading_port_planned_arrival_date: date",
    "loading_port_planned_departure_date: date",
    "loading_tracking_number: string",
    "loading_vessel_name: string",
    "master_bill_of_lading_number: string",
    "mode: string",
    "origin_actual_cargo_ready_date: date",
    "origin_actual_departure_date: date",
    "origin_address: string",
    "origin_appointment_required: string",
    "origin_cfs_actual_arrival_date: date",
    "origin_cfs_actual_departure_date: date",
    "origin_cfs_address: string",
    "origin_cfs_country: string",
    "origin_cfs_estimated_arrival_date: date",
    "origin_cfs_estimated_departure_date: date",
    "origin_cfs_name: string",
    "origin_cfs_planned_arrival_date: date",
    "origin_cfs_planned_departure_date: date",
    "origin_carrier: string",
    "origin_company_name: string",
    "origin_contact_emails: string",
    "origin_contact_names: string",
    "origin_contact_phones: string",
    "origin_country: string",
    "origin_delivery_notes: string",
    "origin_estimated_departure_date: date",
    "origin_name: string",
    "origin_planned_cargo_ready_date: date",
    "origin_planned_departure_date: date",
    "planned_arrival_port_dwell_time: integer",
    "planned_arrival_port_to_delivery_transit_time: integer",
    "planned_crd_to_pickup_dwell_time: integer",
    "planned_departure_port_dwell_time: integer",
    "planned_departure_port_to_arrival_port_transit_time: integer",
    "planned_departure_port_to_discharge_port_transit_time: integer",
    "planned_discharge_port_dwell_time: integer",
    "planned_discharge_port_to_arrival_port_transit_time: integer",
    "planned_door_to_door_transit_time: integer",
    "planned_flexportresponsible_transit_time: integer",
    "planned_pickup_to_departure_port_transit_time: integer",
    "planned_port_to_door_transit_time: integer",
    "planned_port_to_port_transit_time: integer",
    "port_trade_lane: string",
    "priority_shipment: boolean",
    "product_names: string",
    "purchase_order_numbers: string",
    "quote_requested_date: date",
    "quote_shared_date: date",
    "quoted_door_to_door_transit_time: integer",
    "quoted_flexportresponsible_transit_time: integer",
    "quoted_port_to_door_transit_time: integer",
    "quoted_port_to_port_transit_time: integer",
    "rail_shipment: boolean",
    "sku_shipment_tag: string",
    "sku_numbers: string",
    "so_release_date: date",
    "service_level: string",
    "shipment_name: string",
    "shipment_status: string",
    "shipper: string",
    "status_description: string",
    "total_20_ft_containers: integer",
    "total_40_ft_containers: integer",
    "total_40_ft_hc_containers: integer",
    "total_45_ft_hc_containers: integer",
    "total_crd_changes: integer",
    "total_cartons: integer",
    "total_chargeable_volume_cbm: double",
    "total_chargeable_weight_kg: double",
    "total_containers: integer",
    "total_pallets: integer",
    "total_pieces: string",
    "total_product_units: integer",
    "total_teu: integer",
    "total_volume_cbm: double",
    "total_weight_kg: double",
    "console_shipment_tag: string",
    "report_type: string",
]

# %%
patron_list = [
    "flex_id",
    "shipment_name",
    "shipment_status",
    "mode",
    "fcl__lcl",
    "incoterm",
    "quote_requested_date",
    "total_weight_kg",
    "total_chargeable_volume_cbm",
    "total_cartons",
    "total_containers",
    "total_20_ft_containers",
    "total_40_ft_containers",
    "total_40_ft_hc_containers",
    "total_45_ft_hc_containers",
    "product_names",
    "sku_numbers",
    "purchase_order_numbers",
    "total_product_units",
    "total_crd_changes",
    "crd_last_updated_date",
    "origin_name",
    "origin_company_name",
    "origin_address",
    "origin_country",
    "origin_planned_cargo_ready_date",
    "origin_actual_cargo_ready_date",
    "origin_planned_departure_date",
    "origin_estimated_departure_date",
    "origin_actual_departure_date",
    "departure_port",
    "departure_port_country",
    "departure_port_planned_arrival_date",
    "departure_port_estimated_arrival_date",
    "departure_port_actual_arrival_date",
    "departure_port_planned_departure_date",
    "departure_port_estimated_departure_date",
    "departure_port_actual_departure_date",
    "arrival_port",
    "arrival_port_country",
    "destination_planned_arrival_date",
    "destination_estimated_arrival_date",
    "destination_scheduled_delivery_date",
    "destination_actual_arrival_date",
    "sku_shipment_tag",
    "brand_shipment_tag",
    "console_shipment_tag",
    "report_type",
]

# %%
def find_element_index(lst, element):
    for index, item in enumerate(lst):
        if element in item:
            return index
    return None

# %%
final_list = []

for i in patron_list:
    for j in list_to_clean:
        if i in j.lower():
            index = find_element_index(list_to_clean, j)
            final_list.append(list_to_clean[index])

# %%
final_list
# Out:
# ['- column: raw_data.Shipment_Name',
#  'rename_to: shipment_name',
#  '- column: raw_data.Shipment_Status',
#  'rename_to: shipment_status',
#  '- column: raw_data.Mode',
#  'rename_to: mode',
#  '- column: raw_data.FCL__LCL',
#  'rename_to: fcl__lcl',
#  '- column: raw_data.Incoterm',
#  'rename_to: incoterm',
#  '- column: raw_data.Quote_Requested_Date',
#  'rename_to: quote_requested_date',
#  '- column: raw_data.Total_Weight_KG',
#  'rename_to: total_weight_kg',
#  '- column: raw_data.Total_Chargeable_Volume_CBM',
#  'rename_to: total_chargeable_volume_cbm',
#  '- column: raw_data.Total_Cartons',
#  'rename_to: total_cartons',
#  '- column: raw_data.Total_Containers',
#  'rename_to: total_containers',
#  '- column: raw_data.Total_20_ft_Containers',
#  'rename_to: total_20_ft_containers',
#  '- column: raw_data.Total_40_ft_Containers',
#  'rename_to: total_40_ft_containers',
#  '- column: raw_data.Total_40_ft_HC_Containers',
#  'rename_to: total_40_ft_hc_containers',
# ...

# %%
index = find_element_index(list_to_clean, "flex_id")
index
# Out:
# 100

# %%
list_to_clean[index]
# Out:
# 'flex_id: string'
