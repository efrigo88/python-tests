# %%
import pathlib
from datetime import datetime
from typing import List, Tuple, Union, Dict

import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql import Column

from pyspark.sql import DataFrame
from pyspark.sql import SparkSession
from pyspark.sql import Window

# %%
# master configuration to use only 4 CPU cores
spark = SparkSession.builder.master("local[4]").getOrCreate()

# basic configuration to use only a reasonable number of partitions
spark.conf.set("spark.sql.shuffle.partition", 4)

# configuration to work in UTC
spark.conf.set("spark.sql.session.timeZone", "UTC")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/07/12 11:54:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/07/12 11:54:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/07/12 11:54:19 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
path = "/Users/emilianofrigo/Downloads/1689044938226_0.jsonl"

# Read JSONL file
df = (
    spark
    .read
    # .option("multiline", "true")
    .json(path)
)

# %%
df.printSchema()
# Out:
# root
#  |-- _airbyte_ab_id: string (nullable = true)
#  |-- _airbyte_data: struct (nullable = true)
#  |    |-- AdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- PerUnitAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- ProductDescription: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: string (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |    |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentType: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |-- AffordabilityExpenseEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- AffordabilityExpenseReversalEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ChargebackEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- CouponPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- DebtRecoveryEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ChargeInstrumentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |-- Tail: string (nullable = true)
#  |    |    |    |-- DebtRecoveryItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- GroupBeginDate: string (nullable = true)
#  |    |    |    |    |    |-- GroupEndDate: string (nullable = true)
#  |    |    |    |    |    |-- OriginalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- RecoveryAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- DebtRecoveryType: string (nullable = true)
#  |    |    |    |-- RecoveryAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- FBALiquidationEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- GuaranteeClaimEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ImagingServicesFeeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- LoanServicingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- NetworkComminglingTransactionEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ASIN: string (nullable = true)
#  |    |    |    |-- MarketplaceId: string (nullable = true)
#  |    |    |    |-- NetCoTransactionID: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SwapReason: string (nullable = true)
#  |    |    |    |-- TaxAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- PayWithAmazonEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ProductAdsPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- baseValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- invoiceId: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- transactionType: string (nullable = true)
#  |    |    |    |-- transactionValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- RefundEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- RemovalShipmentAdjustmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RemovalShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RentalTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RetrochargeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SAFETReimbursementEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerDealPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerReviewEnrollmentPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ServiceFeeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- FeeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |-- ServiceProviderCreditEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ShipmentSettleEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TaxWithholdingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TrialShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- _airbyte_emitted_at: long (nullable = true)

# %%
df.show(truncate=False)
# Out:
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |_airbyte_ab_id                      |_airbyte_data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |ed84cf8d-05ce-4ae6-8caf-019d7a6b3aba|{[{{-13.49, EUR}, [{{-13.49, EUR}, AMZPET Coprisedile Auto per Cani - Telo Macchina per Cani - Antiscivolo e Antigraffio - Telo Cani Auto Sedili Posteriori - (56x45x122 cm), 1, RS-Y0DR-OIV7, {-13.49, EUR}}], COMPENSATED_CLAWBACK, 2023-07-01T15:58:18Z}, {{11.48, EUR}, [{{11.48, EUR}, AMZPET Protection Voiture Chien Siège Arriere et Enfants Universelle et Imperméable - Housse Voiture Chien - Protege Siege Voiture Chien - Antidéparante et Antigriffures - 56x45x133 cm, 1, RS-Y0DR-OIV7, {11.48, EUR}}], REVERSAL_REIMBURSEMENT, 2023-07-03T19:51:17Z}, {{10.9, EUR}, [{{10.9, EUR}, AMZPET Coprisedile Auto per Cani (Universale: larghezza 133 cm) - Telo Auto per Cani e Idrorepellente, Antiscivolo e Antigraffio - Compatibile con Seggiolini Isofix - 56 x 45 x 133 cm, 1, AMP-TSC-WW-ZZ-IS, {10.9, EUR}}], WAREHOUSE_LOST_MANUAL, 2023-07-04T20:03:35Z}, {{-22.84, EUR}, [{{-11.42, EUR}, AMZPET Protection Voiture Chien - Housse de Siège Voiture pour Chiens - Protection pour Coffres et Sièges Arrières, Imperméable, Lavable, Antidérapante, Universelle (147x137 cm), 2, 1V-5T63-OJXQ, {-22.84, EUR}}], COMPENSATED_CLAWBACK, 2023-07-04T22:57:51Z}, {{-11.48, EUR}, [{{-11.48, EUR}, AMZPET Protection Voiture Chien Siège Arriere et Enfants Universelle et Imperméable - Housse Voiture Chien - Protege Siege Voiture Chien - Antidéparante et Antigriffures - 56x45x133 cm, 1, RS-Y0DR-OIV7, {-11.48, EUR}}], COMPENSATED_CLAWBACK, 2023-07-05T03:07:56Z}, {{1575.83, SEK}, null, ReserveCredit, 2023-07-05T08:26:57Z}, {{-1575.83, SEK}, null, ReserveDebit, 2023-07-05T08:26:57Z}, {{-14.68, EUR}, [{{-14.68, EUR}, AMZPET Funda Coche Perros Asiento Trasero - Cubre Asientos Coche Perro Resistente al Agua y Muy Duradero - Protector Asiento Coche Perro - (56x45x133 cm), 1, RS-Y0DR-OIV7, {-14.68, EUR}}], COMPENSATED_CLAWBACK, 2023-07-05T17:05:55Z}, {{-14.68, EUR}, [{{-14.68, EUR}, AMZPET Funda Coche Perros Asiento Trasero - Cubre Asientos Coche Perro Resistente al Agua y Muy Duradero - Protector Asiento Coche Perro - (56x45x133 cm), 1, RS-Y0DR-OIV7, {-14.68, EUR}}], COMPENSATED_CLAWBACK, 2023-07-05T17:06:11Z}, {{-65.85, EUR}, [{{-13.17, EUR}, AMZPET 3-in-1 Hundedecke Auto Rückbank - Auto Hundedecke Rücksitz - Kofferraumschutz Hund und Hängematte Hund, rutschfest &amp; Kratzfest, wasserdichte (56x45x137x48 cm), 5, 1V-5T63-OJXQ, {-65.85, EUR}}], COMPENSATED_CLAWBACK, 2023-07-06T19:56:04Z}, {{-38.7, EUR}, [{{-12.9, EUR}, AMZPET Funda Coche Perros 3 en 1 - Cubre Asientos Coche Perro Resistente al Agua - Funda Coche Perro Antideslizante - Cubreasientos para Coche con cinturón de Seguridad para Perros - 56x45x137x48 cm, 3, 1V-5T63-OJXQ, {-38.7, EUR}}], COMPENSATED_CLAWBACK, 2023-07-06T20:34:03Z}, {{19.78, EUR}, null, ReserveCredit, 2023-07-07T18:19:31Z}, {{-19.78, EUR}, null, ReserveDebit, 2023-07-07T18:19:31Z}], [], [], [], [], [{[{{352.34, GBP}, Visa, 4088}], [{2023-06-23T11:16:22Z, 2023-07-07T11:29:01Z, {-352.34, GBP}, {352.34, GBP}}], DebtPayment, {352.34, GBP}}, {[{{31.68, EUR}, Visa, 4088}], [{2023-06-24T13:08:35Z, 2023-07-08T13:08:35Z, {-31.68, EUR}, {31.68, EUR}}], DebtPayment, {31.68, EUR}}, {[{{99.99, EUR}, Visa, 4088}], [{2023-06-24T13:08:36Z, 2023-07-08T13:08:36Z, {-99.99, EUR}, {99.99, EUR}}], DebtPayment, {99.99, EUR}}, {[{{72.98, EUR}, Visa, 4088}], [{2023-06-24T13:08:36Z, 2023-07-08T13:08:36Z, {-72.98, EUR}, {72.98, EUR}}], DebtPayment, {72.98, EUR}}, {[{{134.96, EUR}, Visa, 4088}], [{2023-06-24T13:08:36Z, 2023-07-08T13:08:36Z, {-128.49, EUR}, {128.49, EUR}}, {2023-06-10T13:08:35Z, 2023-06-24T13:08:36Z, {-6.47, EUR}, {6.47, EUR}}], DebtPayment, {134.96, EUR}}], [], [], [], [], [{B08PZFHMQZ, A1F83G8C2ARO7P, 1522685343, 2023-07-09T16:31:56Z, Ordering, {4.0, GBP}, ComminglingVAT}, {B08PZFHMQZ, A1F83G8C2ARO7P, 1522685343, 2023-07-09T16:31:56Z, Ordering, {-4.0, GBP}, ComminglingVAT}, {B08PZFHMQZ, A1F83G8C2ARO7P, 1522690553, 2023-07-09T16:42:57Z, Ordering, {4.0, GBP}, ComminglingVAT}, {B08PZFHMQZ, A1F83G8C2ARO7P, 1522690553, 2023-07-09T16:42 ...
# +------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
def explode(df: DataFrame, config: dict) -> DataFrame:
    columns = config["columns"]
    
    if not isinstance(columns, list):
        columns = [columns]
        print(columns)

    for column in columns:
        df.withColumn(column, F.explode(column))
    
    return df

# %%
def unnest(df: DataFrame, config: dict) -> DataFrame:
    for column in config["columns"]:
        column_to_extract = column["column"]
        new_name = column["rename_to"]
        df = df.withColumn(new_name, F.col(column_to_extract))
    return df

# %%
explode_dict = {
    "columns":"_airbyte_data.ShipmentEventList",
}

# %%
df_exploded = explode(df=df, config=explode_dict)

#df_exploded.printSchema()
df_exploded.show()
# Out:
# +--------------------+--------------------+-------------------+
# |      _airbyte_ab_id|       _airbyte_data|_airbyte_emitted_at|
# +--------------------+--------------------+-------------------+
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|
# +--------------------+--------------------+-------------------+

# %%
df_manual_explode = (
    df
    .withColumn("ShipmentEventList", F.explode("_airbyte_data.ShipmentEventList"))
)

# %%
df_manual_explode.printSchema()
# Out:
# root
#  |-- _airbyte_ab_id: string (nullable = true)
#  |-- _airbyte_data: struct (nullable = true)
#  |    |-- AdjustmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AdjustmentAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- PerUnitAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- ProductDescription: string (nullable = true)
#  |    |    |    |    |    |-- Quantity: string (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |    |    |    |    |-- TotalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- AdjustmentType: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |-- AffordabilityExpenseEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- AffordabilityExpenseReversalEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ChargebackEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- CouponPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- DebtRecoveryEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ChargeInstrumentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- Amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- Description: string (nullable = true)
#  |    |    |    |    |    |-- Tail: string (nullable = true)
#  |    |    |    |-- DebtRecoveryItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- GroupBeginDate: string (nullable = true)
#  |    |    |    |    |    |-- GroupEndDate: string (nullable = true)
#  |    |    |    |    |    |-- OriginalAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- RecoveryAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- DebtRecoveryType: string (nullable = true)
#  |    |    |    |-- RecoveryAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- FBALiquidationEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- GuaranteeClaimEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ImagingServicesFeeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- LoanServicingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- NetworkComminglingTransactionEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ASIN: string (nullable = true)
#  |    |    |    |-- MarketplaceId: string (nullable = true)
#  |    |    |    |-- NetCoTransactionID: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SwapReason: string (nullable = true)
#  |    |    |    |-- TaxAmount: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- TransactionType: string (nullable = true)
#  |    |-- PayWithAmazonEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ProductAdsPaymentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- baseValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- invoiceId: string (nullable = true)
#  |    |    |    |-- postedDate: string (nullable = true)
#  |    |    |    |-- taxValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |-- transactionType: string (nullable = true)
#  |    |    |    |-- transactionValue: struct (nullable = true)
#  |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |-- RefundEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemAdjustmentList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeAdjustmentList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderAdjustmentItemId: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- RemovalShipmentAdjustmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RemovalShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RentalTransactionEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- RetrochargeEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SAFETReimbursementEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerDealPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- SellerReviewEnrollmentPaymentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ServiceFeeEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- FeeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |-- ServiceProviderCreditEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ShipmentEventList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- AmazonOrderId: string (nullable = true)
#  |    |    |    |-- MarketplaceName: string (nullable = true)
#  |    |    |    |-- PostedDate: string (nullable = true)
#  |    |    |    |-- SellerOrderId: string (nullable = true)
#  |    |    |    |-- ShipmentItemList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ItemChargeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemFeeList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |    |    |-- OrderItemId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionList: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |    |    |-- SellerSKU: string (nullable = true)
#  |    |-- ShipmentSettleEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TaxWithholdingEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- TrialShipmentEventList: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- _airbyte_emitted_at: long (nullable = true)
#  |-- ShipmentEventList: struct (nullable = true)
#  |    |-- AmazonOrderId: string (nullable = true)
#  |    |-- MarketplaceName: string (nullable = true)
#  |    |-- PostedDate: string (nullable = true)
#  |    |-- SellerOrderId: string (nullable = true)
#  |    |-- ShipmentItemList: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ItemChargeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- ItemFeeList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- FeeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- FeeType: string (nullable = true)
#  |    |    |    |-- ItemTaxWithheldList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- TaxCollectionModel: string (nullable = true)
#  |    |    |    |    |    |-- TaxesWithheld: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- ChargeAmount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ChargeType: string (nullable = true)
#  |    |    |    |-- OrderItemId: string (nullable = true)
#  |    |    |    |-- PromotionList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- PromotionAmount: struct (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyAmount: double (nullable = true)
#  |    |    |    |    |    |    |-- CurrencyCode: string (nullable = true)
#  |    |    |    |    |    |-- PromotionId: string (nullable = true)
#  |    |    |    |    |    |-- PromotionType: string (nullable = true)
#  |    |    |    |-- QuantityShipped: long (nullable = true)
#  |    |    |    |-- SellerSKU: string (nullable = true)

# %%
unnest_cols = {
    "columns": [
        {"column": "ShipmentEventList.AmazonOrderId", "rename_to": "amazon_order_id"},
    ]
}

# df_unnested = unnest(df_manual_explode, unnest_cols)

# %%
for column in unnest_cols["columns"]:
    print(column)
    column_to_extract = column["column"]
    new_name = column["rename_to"]
    df_manual_explode2 = df_manual_explode.withColumn(new_name, F.col(column_to_extract))
# Out:
# {'column': 'ShipmentEventList.AmazonOrderId', 'rename_to': 'amazon_order_id'}

# %%
df_manual_explode2.show()
# Out:
# +--------------------+--------------------+-------------------+--------------------+-------------------+
# |      _airbyte_ab_id|       _airbyte_data|_airbyte_emitted_at|   ShipmentEventList|    amazon_order_id|
# +--------------------+--------------------+-------------------+--------------------+-------------------+
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{202-7551542-5478...|202-7551542-5478708|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{026-0479204-0943...|026-0479204-0943514|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{204-6668810-1251...|204-6668810-1251519|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{171-8643008-7651...|171-8643008-7651515|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{206-1458711-5286...|206-1458711-5286725|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{202-4247892-6654...|202-4247892-6654724|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{204-3557912-6502...|204-3557912-6502702|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{405-6899873-2081...|405-6899873-2081911|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{404-4758060-9012...|404-4758060-9012362|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{204-1806531-4503...|204-1806531-4503514|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{205-7885013-2972...|205-7885013-2972327|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{202-3669245-9045...|202-3669245-9045128|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{205-3932327-7361...|205-3932327-7361159|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{406-7430144-7486...|406-7430144-7486761|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{203-3152926-8357...|203-3152926-8357935|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{206-8350525-8197...|206-8350525-8197103|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{171-8106698-0430...|171-8106698-0430751|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{302-2320566-9922...|302-2320566-9922713|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{205-1727035-6509...|205-1727035-6509952|
# |ed84cf8d-05ce-4ae...|{[{{-13.49, EUR},...|      1689044967267|{404-6128770-5852...|404-6128770-5852308|
# +--------------------+--------------------+-------------------+--------------------+-------------------+
# only showing top 20 rows
