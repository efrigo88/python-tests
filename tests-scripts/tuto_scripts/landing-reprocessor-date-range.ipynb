# %%
import boto3

env = 'prod'
aws_session = boto3.session.Session(profile_name=f'data-maintainer-{env}')
s3_client = aws_session.client('s3')
lambda_client = aws_session.client('lambda')
s3 = aws_session.resource('s3')

landing_bucket = s3.Bucket(f'f14-datalake-landing-{env}')
input_bucket = f'f14-datalake-landing-{env}'
output_bucket = f'f14-datalake-raw-{env}'
base_prefix = 'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/'

# %%
import json 
from datetime import datetime
import tempfile
import progressbar
from datetime import datetime
import pathlib
import os


def get_files_to_proccess(valid_prefix):
    files_to_process = []
    for landing_bucket_object in landing_bucket.objects.all():
        object_last_update = landing_bucket_object.last_modified
        bucket_name = landing_bucket_object.bucket_name
        object_key = landing_bucket_object.key

        if valid_prefix in object_key and ('.csv' in object_key or '.tsv' in object_key or '.jsonl' in object_key):
            files_to_process.append([bucket_name, object_key, object_last_update])   
    
    return files_to_process


def get_lambda_payload(bucket_name, object_prefix, file_last_update_ts):
    return {
              "Records": [
                {
                  "eventVersion": "2.0",
                  "eventSource": "aws:s3",
                  "awsRegion": "us-east-1",
                  "eventTime": "1970-01-01T00:00:00.000Z",
                  "eventName": "ObjectCreated:Put",
                  "userIdentity": {
                    "principalId": "EXAMPLE"
                  },
                  "requestParameters": {
                    "sourceIPAddress": "127.0.0.1"
                  },
                  "responseElements": {
                    "x-amz-request-id": "EXAMPLE123456789",
                    "x-amz-id-2": "EXAMPLE123/5678abcdefghijklambdaisawesome/mnopqrstuvwxyzABCDEFGH"
                  },
                  "s3": {
                    "s3SchemaVersion": "1.0",
                    "configurationId": "testConfigRule",
                    "bucket": {
                      "name": bucket_name,
                      "ownerIdentity": {
                        "principalId": "EXAMPLE"
                      },
                      "arn": f"arn:aws:s3:::{bucket_name}"
                    },
                    "object": {
                      "key": object_prefix,
                      "size": 1024,
                      "eTag": "0123456789abcdef0123456789abcdef",
                      "sequencer": "0A1B2C3D4E5F678901"
                    }
                  }
                }
              ]
            }

# %%
import time
import progressbar
import io

files_to_process_all = get_files_to_proccess(base_prefix)
len(files_to_process_all)
# Out:
# 10356

# %%
files_to_process_all[:5]
# Out:
# [['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2021-10-27/p_brand_id=BARVIVO/p_region_id=EU/768408018927.tsv',
#   datetime.datetime(2021, 11, 25, 14, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2021-10-27/p_brand_id=BARVIVO/p_region_id=EU/768411018927.tsv',
#   datetime.datetime(2021, 11, 25, 14, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2021-10-27/p_brand_id=BARVIVO/p_region_id=EU/768415018927.tsv',
#   datetime.datetime(2021, 11, 25, 14, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2021-10-27/p_brand_id=BARVIVO/p_region_id=EU/768419018927.tsv',
#   datetime.datetime(2021, 11, 25, 14, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2021-10-27/p_brand_id=BARVIVO/p_region_id=EU/768428018927.tsv',
#   datetime.datetime(2021, 11, 25, 14, 2, 6, tzinfo=tzutc())]]

# %%
date_from = "2022-03-02"
date_to = "2022-03-11"
region = "p_region_id=US"

# %%
files_to_process = []

for bucket, file, datetime_ in files_to_process_all:
    if region in file:
        pos = file.find("=")
        dt = file[pos+1:pos+11]
        # print(file)
        # print(pos)
        # print(dt)
        if date_from <= dt <= date_to:
            files_to_process.append([bucket, file, datetime_])

# %%
files_to_process
# Out:
# [['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691312019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691385019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691463019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691544019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691554019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BARVIVO/p_region_id=US/691636019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BLACKRHINO/p_region_id=US/270911019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BLACKRHINO/p_region_id=US/270973019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 0, 13, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BLACKRHINO/p_region_id=US/271024019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BLACKRHINO/p_region_id=US/271077019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=BLACKRHINO/p_region_id=US/271131019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209548019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209626019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209702019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209805019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209884019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/596827019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/596873019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/596928019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/596984019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597023019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=OUTLERY/p_region_id=US/106550019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=OUTLERY/p_region_id=US/106577019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=OUTLERY/p_region_id=US/106621019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=OUTLERY/p_region_id=US/106653019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=PROBIKETOOLS/p_region_id=US/564873019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=PROBIKETOOLS/p_region_id=US/565001019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=PROBIKETOOLS/p_region_id=US/565126019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=PROBIKETOOLS/p_region_id=US/565250019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=PROBIKETOOLS/p_region_id=US/565371019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SILVON/p_region_id=US/123454019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SILVON/p_region_id=US/123514019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SILVON/p_region_id=US/123579019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SILVON/p_region_id=US/123666019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SILVON/p_region_id=US/123729019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SWEETVIBES/p_region_id=US/200340019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SWEETVIBES/p_region_id=US/200387019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SWEETVIBES/p_region_id=US/200424019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SWEETVIBES/p_region_id=US/200477019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=SWEETVIBES/p_region_id=US/200516019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TOOLZILLA/p_region_id=US/106995019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TOOLZILLA/p_region_id=US/107025019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TOOLZILLA/p_region_id=US/107050019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TOOLZILLA/p_region_id=US/107094019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TOOLZILLA/p_region_id=US/107119019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 0, 10, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TRIBEWOD/p_region_id=US/85256019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TRIBEWOD/p_region_id=US/85295019053.tsv',
#   datetime.datetime(2022, 3, 2, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TRIBEWOD/p_region_id=US/85348019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 0, 17, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=TRIBEWOD/p_region_id=US/85392019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=WWO/p_region_id=US/393961019052.tsv',
#   datetime.datetime(2022, 3, 2, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=WWO/p_region_id=US/394012019053.tsv',
#   datetime.datetime(2022, 3, 2, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=WWO/p_region_id=US/394067019053.tsv',
#   datetime.datetime(2022, 3, 2, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=WWO/p_region_id=US/394127019053.tsv',
#   datetime.datetime(2022, 3, 2, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-02/p_brand_id=WWO/p_region_id=US/394177019053.tsv',
#   datetime.datetime(2022, 3, 2, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BARVIVO/p_region_id=US/691716019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BARVIVO/p_region_id=US/691804019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BARVIVO/p_region_id=US/691886019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BARVIVO/p_region_id=US/691966019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BARVIVO/p_region_id=US/692038019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BLACKRHINO/p_region_id=US/271203019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BLACKRHINO/p_region_id=US/271255019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 0, 16, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BLACKRHINO/p_region_id=US/271309019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=BLACKRHINO/p_region_id=US/271354019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=KETTLEBELLKINGS/p_region_id=US/209954019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210030019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210125019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210211019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210280019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597066019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597120019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597165019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597223019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597260019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=OUTLERY/p_region_id=US/106677019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=OUTLERY/p_region_id=US/106709019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 0, 12, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=OUTLERY/p_region_id=US/106736019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=OUTLERY/p_region_id=US/106778019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=OUTLERY/p_region_id=US/106810019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=PROBIKETOOLS/p_region_id=US/565492019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=PROBIKETOOLS/p_region_id=US/565612019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=PROBIKETOOLS/p_region_id=US/565765019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=PROBIKETOOLS/p_region_id=US/565883019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=PROBIKETOOLS/p_region_id=US/565993019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SILVON/p_region_id=US/123806019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SILVON/p_region_id=US/123865019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SILVON/p_region_id=US/123928019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SILVON/p_region_id=US/124016019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SWEETVIBES/p_region_id=US/200559019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SWEETVIBES/p_region_id=US/200602019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 0, 12, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SWEETVIBES/p_region_id=US/200654019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SWEETVIBES/p_region_id=US/200689019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=SWEETVIBES/p_region_id=US/200730019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TOOLZILLA/p_region_id=US/107143019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TOOLZILLA/p_region_id=US/107177019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TOOLZILLA/p_region_id=US/107203019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TOOLZILLA/p_region_id=US/107247019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TOOLZILLA/p_region_id=US/107270019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TRIBEWOD/p_region_id=US/85429019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TRIBEWOD/p_region_id=US/85474019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TRIBEWOD/p_region_id=US/85513019054.tsv',
#   datetime.datetime(2022, 3, 3, 8, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TRIBEWOD/p_region_id=US/85563019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=TRIBEWOD/p_region_id=US/85604019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=WWO/p_region_id=US/394227019053.tsv',
#   datetime.datetime(2022, 3, 3, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=WWO/p_region_id=US/394280019054.tsv',
#   datetime.datetime(2022, 3, 3, 4, 0, 16, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=WWO/p_region_id=US/394333019054.tsv',
#   datetime.datetime(2022, 3, 3, 12, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=WWO/p_region_id=US/394395019054.tsv',
#   datetime.datetime(2022, 3, 3, 14, 40, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-03/p_brand_id=WWO/p_region_id=US/394443019054.tsv',
#   datetime.datetime(2022, 3, 3, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BARVIVO/p_region_id=US/692122019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BARVIVO/p_region_id=US/692205019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 0, 13, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BARVIVO/p_region_id=US/692289019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BARVIVO/p_region_id=US/692367019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 0, 12, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BARVIVO/p_region_id=US/692459019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BLACKRHINO/p_region_id=US/271398019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BLACKRHINO/p_region_id=US/271454019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BLACKRHINO/p_region_id=US/271503019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BLACKRHINO/p_region_id=US/271563019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=BLACKRHINO/p_region_id=US/271620019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210356019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210435019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210528019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210620019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210693019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597322019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597368019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597418019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597462019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=OUTLERY/p_region_id=US/106839019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=OUTLERY/p_region_id=US/106871019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=OUTLERY/p_region_id=US/106899019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=OUTLERY/p_region_id=US/106947019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 0, 12, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=OUTLERY/p_region_id=US/106972019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 0, 16, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=PROBIKETOOLS/p_region_id=US/566133019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=PROBIKETOOLS/p_region_id=US/566262019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=PROBIKETOOLS/p_region_id=US/566397019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=PROBIKETOOLS/p_region_id=US/566515019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SILVON/p_region_id=US/124086019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SILVON/p_region_id=US/124145019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SILVON/p_region_id=US/124205019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SILVON/p_region_id=US/124313019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SILVON/p_region_id=US/124369019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SWEETVIBES/p_region_id=US/200770019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SWEETVIBES/p_region_id=US/200812019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SWEETVIBES/p_region_id=US/200865019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SWEETVIBES/p_region_id=US/200903019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=SWEETVIBES/p_region_id=US/200946019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 0, 17, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TOOLZILLA/p_region_id=US/107301019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TOOLZILLA/p_region_id=US/107338019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 0, 10, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TOOLZILLA/p_region_id=US/107362019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TOOLZILLA/p_region_id=US/107395019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 0, 13, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TOOLZILLA/p_region_id=US/107420019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TRIBEWOD/p_region_id=US/85644019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TRIBEWOD/p_region_id=US/85685019055.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TRIBEWOD/p_region_id=US/85733019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TRIBEWOD/p_region_id=US/85781019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=TRIBEWOD/p_region_id=US/85823019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=WWO/p_region_id=US/394495019054.tsv',
#   datetime.datetime(2022, 3, 4, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=WWO/p_region_id=US/394548019055.tsv',
#   datetime.datetime(2022, 3, 4, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=WWO/p_region_id=US/394598019055.tsv',
#   datetime.datetime(2022, 3, 4, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=WWO/p_region_id=US/394657019055.tsv',
#   datetime.datetime(2022, 3, 4, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-04/p_brand_id=WWO/p_region_id=US/394708019055.tsv',
#   datetime.datetime(2022, 3, 4, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BARVIVO/p_region_id=US/692554019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BARVIVO/p_region_id=US/692642019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 0, 11, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BARVIVO/p_region_id=US/692719019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BARVIVO/p_region_id=US/692811019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BLACKRHINO/p_region_id=US/271669019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BLACKRHINO/p_region_id=US/271729019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BLACKRHINO/p_region_id=US/271786019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BLACKRHINO/p_region_id=US/271842019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=BLACKRHINO/p_region_id=US/271896019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210776019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210849019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=KETTLEBELLKINGS/p_region_id=US/210949019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=KETTLEBELLKINGS/p_region_id=US/211024019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597512019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597560019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597606019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597664019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/597703019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=OUTLERY/p_region_id=US/107000019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=OUTLERY/p_region_id=US/107034019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=OUTLERY/p_region_id=US/107061019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=OUTLERY/p_region_id=US/107103019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=OUTLERY/p_region_id=US/107132019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=PROBIKETOOLS/p_region_id=US/566632019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=PROBIKETOOLS/p_region_id=US/566758019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=PROBIKETOOLS/p_region_id=US/566883019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=PROBIKETOOLS/p_region_id=US/567013019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=PROBIKETOOLS/p_region_id=US/567121019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SILVON/p_region_id=US/124434019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SILVON/p_region_id=US/124500019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SILVON/p_region_id=US/124567019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SILVON/p_region_id=US/124653019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SILVON/p_region_id=US/124706019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SWEETVIBES/p_region_id=US/200991019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SWEETVIBES/p_region_id=US/201036019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SWEETVIBES/p_region_id=US/201085019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SWEETVIBES/p_region_id=US/201123019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=SWEETVIBES/p_region_id=US/201159019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 0, 11, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TOOLZILLA/p_region_id=US/107456019056.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TOOLZILLA/p_region_id=US/107482019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TOOLZILLA/p_region_id=US/107520019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TOOLZILLA/p_region_id=US/107550019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TRIBEWOD/p_region_id=US/85861019055.tsv',
#   datetime.datetime(2022, 3, 5, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TRIBEWOD/p_region_id=US/85913019056.tsv',
#   datetime.datetime(2022, 3, 5, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TRIBEWOD/p_region_id=US/85951019056.tsv',
#   datetime.datetime(2022, 3, 5, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TRIBEWOD/p_region_id=US/85998019056.tsv',
#   datetime.datetime(2022, 3, 5, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-05/p_brand_id=TRIBEWOD/p_region_id=US/86032019056.tsv',
#   datetime.datetime(2022, 3, 5, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
# ...
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/598772019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/598825019061.tsv',
#   datetime.datetime(2022, 3, 10, 16, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/598865019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=OUTLERY/p_region_id=US/107795019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=OUTLERY/p_region_id=US/107819019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=OUTLERY/p_region_id=US/107867019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=OUTLERY/p_region_id=US/107896019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=PROBIKETOOLS/p_region_id=US/569690019060.tsv',
#   datetime.datetime(2022, 3, 10, 4, 4, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=PROBIKETOOLS/p_region_id=US/569820019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=PROBIKETOOLS/p_region_id=US/569937019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=PROBIKETOOLS/p_region_id=US/570077019061.tsv',
#   datetime.datetime(2022, 3, 10, 16, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=PROBIKETOOLS/p_region_id=US/570195019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SILVON/p_region_id=US/126086019060.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SILVON/p_region_id=US/126154019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SILVON/p_region_id=US/126216019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SILVON/p_region_id=US/126296019061.tsv',
#   datetime.datetime(2022, 3, 10, 16, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SILVON/p_region_id=US/126350019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SWEETVIBES/p_region_id=US/202117019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SWEETVIBES/p_region_id=US/202166019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SWEETVIBES/p_region_id=US/202212019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=SWEETVIBES/p_region_id=US/202257019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TOOLZILLA/p_region_id=US/108183019060.tsv',
#   datetime.datetime(2022, 3, 10, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TOOLZILLA/p_region_id=US/108223019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TOOLZILLA/p_region_id=US/108268019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TOOLZILLA/p_region_id=US/108319019061.tsv',
#   datetime.datetime(2022, 3, 10, 16, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TOOLZILLA/p_region_id=US/108354019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TRIBEWOD/p_region_id=US/86931019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TRIBEWOD/p_region_id=US/86972019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TRIBEWOD/p_region_id=US/87021019061.tsv',
#   datetime.datetime(2022, 3, 10, 12, 0, 14, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=TRIBEWOD/p_region_id=US/87064019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=WWO/p_region_id=US/395995019060.tsv',
#   datetime.datetime(2022, 3, 10, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=WWO/p_region_id=US/396051019061.tsv',
#   datetime.datetime(2022, 3, 10, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=WWO/p_region_id=US/396098019061.tsv',
#   datetime.datetime(2022, 3, 10, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=WWO/p_region_id=US/396158019061.tsv',
#   datetime.datetime(2022, 3, 10, 16, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-10/p_brand_id=WWO/p_region_id=US/396212019061.tsv',
#   datetime.datetime(2022, 3, 10, 20, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BARVIVO/p_region_id=US/694848019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 4, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BARVIVO/p_region_id=US/694921019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BARVIVO/p_region_id=US/695005019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BLACKRHINO/p_region_id=US/273303019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BLACKRHINO/p_region_id=US/273357019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=BLACKRHINO/p_region_id=US/273404019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=KETTLEBELLKINGS/p_region_id=US/213068019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 6, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=KETTLEBELLKINGS/p_region_id=US/213122019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 4, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=KETTLEBELLKINGS/p_region_id=US/213151019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=KETTLEBELLKINGS/p_region_id=US/213220019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 9, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/598908019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/598963019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=MOUNTAIN_GRILLERS/p_region_id=US/599015019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=OUTLERY/p_region_id=US/107923019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=OUTLERY/p_region_id=US/107958019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 0, 15, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=OUTLERY/p_region_id=US/107985019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=PROBIKETOOLS/p_region_id=US/570316019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=PROBIKETOOLS/p_region_id=US/570444019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=PROBIKETOOLS/p_region_id=US/570579019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SILVON/p_region_id=US/126433019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SILVON/p_region_id=US/126493019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SILVON/p_region_id=US/126553019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 8, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SWEETVIBES/p_region_id=US/202302019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SWEETVIBES/p_region_id=US/202348019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=SWEETVIBES/p_region_id=US/202401019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TOOLZILLA/p_region_id=US/108394019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 5, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TOOLZILLA/p_region_id=US/108437019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 0, 13, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TOOLZILLA/p_region_id=US/108481019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TRIBEWOD/p_region_id=US/87104019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TRIBEWOD/p_region_id=US/87148019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=TRIBEWOD/p_region_id=US/87190019062.tsv',
#   datetime.datetime(2022, 3, 11, 8, 2, 7, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=WWO/p_region_id=US/396259019061.tsv',
#   datetime.datetime(2022, 3, 11, 4, 4, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=WWO/p_region_id=US/396322019062.tsv',
#   datetime.datetime(2022, 3, 11, 4, 2, 6, tzinfo=tzutc())],
#  ['f14-datalake-landing-prod',
#   'amazon_sp_api/GET_FBA_FULFILLMENT_CURRENT_INVENTORY_DATA/p_creation_dt=2022-03-11/p_brand_id=WWO/p_region_id=US/396367019062.tsv',
#   datetime.datetime(2022, 3, 11, 12, 2, 7, tzinfo=tzutc())]]

# %%
len(files_to_process)
# Out:
# 498

# %%
import json
from time import sleep

i = 0
with progressbar.ProgressBar(max_value=len(files_to_process)) as bar:
    for file_to_process in files_to_process:   
        call_payload = get_lambda_payload(file_to_process[0], file_to_process[1], file_to_process[2])

        response = lambda_client.invoke_async(
            FunctionName='landingFileProcessor',
            InvokeArgs=json.dumps(call_payload),
        )
        sleep(2)          
        i = i + 1
        bar.update(i)

print("Done!")
# Out:
# 100% (498 of 498) |######################| Elapsed Time: 0:17:21 Time:  0:17:21
# Done!
