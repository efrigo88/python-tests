# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/emif/Downloads/733631018986.tsv", sep="\t", encoding="utf-8-sig"
)

# %%
df.head(8)
# Out:
#   Country                                       Product Name       FNSKU  \
# 0      GB  TOOLZILLA Heavy Duty 18 Piece Hex Key (Allen K...  B0785KWZNX
# 1      GB  TOOLZILLA 14mm Heavy Duty Galvanised Staples f...  B08L6ZM6M8
# 2      GB  TOOLZILLA Screwdriver Set, 10 Piece Magnetic S...  B077XXSW25
# 3      GB  TOOLZILLA Professional 9 Piece Magnetic Screwd...  B08KQJB9MC
# 4      GB  TOOLZILLA 4-in-1 Professional Heavy Duty Stapl...  B08LQKWLWP
# 5      GB  TOOLZILLA Professional 36 Piece Magnetic Screw...  B08KQJKD5N
# 6      GB  TOOLZILLA Pro LED Head Torch Headlamp, 500 Lum...  B07H72CY7B
# 7      GB  TOOLZILLAÂ® Heavy Duty Staple Gun & Staple Sel...  B01L7ZCQ76
#
#   Merchant SKU        ASIN Condition Supplier  Supplier part no.  \
# 0        TZ002  B0785KWZNX       New       --                NaN
# 1        TZ016  B08L6ZM6M8       New       --                NaN
# 2        TZ003  B077XXSW25       New       --                NaN
# ...
